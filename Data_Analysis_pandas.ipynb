# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("pandas/housing.csv")

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df['waterfront'].value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df.groupby(by="zipcode").sum('price').sort_values('price', ascending=False)
# Out:
#                     id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# zipcode
# 98004    1392973274614  429828890      1222     801.25       922160   4154038
# 98006    2301377943859  428123012      1913    1272.75      1438371   6664951
# 98052    2865936978560  370362854      2076    1357.25      1356738   6384035
# 98115    3181992104222  361402021      1868    1088.25      1069977   3173936
# 98103    2832107114237  352121365      1842    1164.75       993800   2096432
# ...                ...        ...       ...        ...          ...       ...
# 98002     965327932213   46622523       662     366.00       323921   1496009
# 98010     387919540667   42366599       329     202.75       213759   5546530
# 98188     609531729428   39314655       467     253.50       245177   1377147
# 98032     568615104394   31412030       424     213.50       217256   1297470
# 98148     318029151802   16239790       179     102.25        91800    510761
#
# ...

# %%
df.sort_values('price',ascending=False).head(1)['zipcode']
# Out:
# 7252    98102
# Name: zipcode, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
df['id'].nunique()
# Out:
# 21436

# %%
df[df['id'] ==  9126100861][]
# Out:
#              id             date   price  bedrooms  bathrooms  sqft_living  \
# 400  9126100861  20150306T000000  557000         3        3.5         1710
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 400      2096     2.0           0     0  ...      8        1290
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 400            420      2008             0    98122  47.6055 -122.305
#
#      sqft_living15  sqft_lot15
# 400           1630        1543
#
# [1 rows x 21 columns]

# %%
df[df['view'] == 3]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 15     9297300055  20150124T000000   650000         4       3.00         2950
# 60     1516000055  20141210T000000   650000         3       2.25         2150
# 114    8961960160  20141028T000000   480000         4       2.50         3230
# 153    7855801670  20150401T000000  2250000         4       3.25         5180
# 216      46100204  20150221T000000  1505000         5       3.00         3300
# ...           ...              ...      ...       ...        ...          ...
# 21327  7394400080  20150304T000000   535000         4       3.25         2840
# 21344  8835770170  20140822T000000  1488000         5       6.00         6880
# 21505  9468200109  20140617T000000  1555000         3       3.50         4360
# 21539  8902000201  20150219T000000   338500         3       2.25         1333
# 21540   715010530  20150113T000000  1881583         5       3.50         4410
#
# ...

# %%
df['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
df.sort_values('price')
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000    75000         1       0.00          670
# 15293    40000362  20140506T000000    78000         2       1.00          780
# 465    8658300340  20140523T000000    80000         1       0.75          430
# 16198  3028200080  20150324T000000    81000         2       1.00          730
# 8274   3883800011  20141105T000000    82000         3       1.00          860
# ...           ...              ...      ...       ...        ...          ...
# 1448   8907500070  20150413T000000  5350000         5       5.00         8000
# 4411   2470100110  20140804T000000  5570000         5       5.75         9200
# 9254   9208900037  20140919T000000  6885000         6       7.75         9890
# 3914   9808700762  20140611T000000  7062500         5       4.50        10040
# 7252   6762700020  20141013T000000  7700000         6       8.00        12050
#
# ...

# %%
df.sort_values('price').head(1)['zipcode']
# Out:
# 1149    98022
# Name: zipcode, dtype: int64

# %%
df.sort_values('sqft_living',ascending=False).head(1)['zipcode']
# Out:
# 12777    98053
# Name: zipcode, dtype: int64

# %%
df.sort_values('price',ascending=False).head(1)['yr_built']
# Out:
# 7252    1910
# Name: yr_built, dtype: int64

# %%
def increase_grade(data):
    if(data['sqft_living'] > 0 and data['sqft_living'] <= 400):
        return data['grade'] + 1
    elif(data['sqft_living'] > 400):
        return data['grade'] + 2

# %%
df.apply(increase_grade, axis=1)
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df['grade'].isnull().sum()
# Out:
# 0

# %%
df['grade'] = df['grade']-1

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
df[df.duplicated(['id'])]
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 94     6021501535  20141223T000000   700000         3       1.50         1580
# 314    4139480200  20141209T000000  1400000         4       3.25         4290
# 325    7520000520  20150311T000000   240500         2       1.00         1240
# 346    3969300030  20141229T000000   239900         4       1.00         1000
# 372    2231500030  20150324T000000   530000         4       2.25         2180
# ...           ...              ...      ...       ...        ...          ...
# 20181  7853400250  20150219T000000   645000         4       3.50         2910
# 20613  2724049222  20141201T000000   220000         2       2.50         1000
# 20670  8564860270  20150330T000000   502000         4       2.50         2680
# 20780  6300000226  20150504T000000   380000         4       1.00         1200
# 21581  7853420110  20150504T000000   625000         3       3.00         2780
#
# ...

# %%
df.duplicated(subset=['id','zipcode','grade']).sum()
# Out:
# 177

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 df.duplicate(subset=['id','zipcode','grade'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'

# %%
df.iloc[3:6,6:10]
# Out:
#    sqft_lot  floors  waterfront  view
# 3      5000     1.0           0     0
# 4      8080     1.0           0     0
# 5    101930     1.0           0     0

# %%
df1 = pd.DataFrame({'A':[34, 78, 54], 'B':[12, 67, 43]}, index=['r1', 'r2', 'r3'])

# %%
df1
# Out:
#      A   B
# r1  34  12
# r2  78  67
# r3  54  43

# %%
df1.loc['r2':'r3']
# Out:
#      A   B
# r2  78  67
# r3  54  43

# %%
pd.to_datetime(['01-16-2024'], format='%Y-%m-%d', utc=False, dayfirst=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 pd.to_datetime(['01-16-2024'], format='%Y-%m-%d', utc=False, dayfirst=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1100, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1098         result = _convert_and_box_cache(argc, cache_array)
#    1099     else:
# -> 1100         result = convert_listlike(argc, format)
#    1101 else:
#    1102     result = convert_listlike(np.array([arg]), format)[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# ...

# %%
df.loc[df['yr_built'] < 1980]
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 7      2008000270  20150115T000000  291850         3       1.50         1060
# ...           ...              ...     ...       ...        ...          ...
# 21303   522059130  20150429T000000  465000         3       1.00         1150
# 21332  9266700190  20150511T000000  245000         1       1.00          390
# 21343  2924079034  20140925T000000  332220         3       1.50         2580
# 21470   121039156  20150109T000000  249000         3       1.00         1030
# 21583  2025049203  20140610T000000  399950         2       1.00          710
#
# ...

# %%
sample_dict = {'Cristiano': ['Ronaldo','Man U', 801],
'Lionel': ['Messi','PSG', 758],
'Luis': ['Suarez','Atletico Madrid', 509],
'Robert': ['Lewandowski','Bayern Munich', 527],
'Zlatan': ['Ibrahimovic','AC Milan',553]
}

# %%
df3 = pd.DataFrame(sample_dict)

# %%
df3
# Out:
#   Cristiano Lionel             Luis         Robert       Zlatan
# 0   Ronaldo  Messi           Suarez    Lewandowski  Ibrahimovic
# 1     Man U    PSG  Atletico Madrid  Bayern Munich     AC Milan
# 2       801    758              509            527          553

# %%
df3 = df3.transpose()

# %%
df3
# Out:
#                      0                1    2
# Cristiano      Ronaldo            Man U  801
# Lionel           Messi              PSG  758
# Luis            Suarez  Atletico Madrid  509
# Robert     Lewandowski    Bayern Munich  527
# Zlatan     Ibrahimovic         AC Milan  553

# %%
df3.reset_index(inplace = True)

# %%
df3.columns = ['First Name','Last Name', 'Club', 'Goals']

# %%
df3
# Out:
#   First Name    Last Name             Club Goals
# 0  Cristiano      Ronaldo            Man U   801
# 1     Lionel        Messi              PSG   758
# 2       Luis       Suarez  Atletico Madrid   509
# 3     Robert  Lewandowski    Bayern Munich   527
# 4     Zlatan  Ibrahimovic         AC Milan   553

# %%
sample_tuple = ([1, 'one', 3],[2, 'two', 3],[3, 'Three', 5],[4, 'Four', 4],[5, 'Five', 4])

# %%
df4 = pd.DataFrame(sample_tuple)

# %%
df4.columns = ['Number', 'Number_text', 'txtlen']

# %%
df4
# Out:
#    Number Number_text  txtlen
# 0       1         one       3
# 1       2         two       3
# 2       3       Three       5
# 3       4        Four       4
# 4       5        Five       4

# %%
df.loc[25:35]
# Out:
#             id             date   price  bedrooms  bathrooms  sqft_living  \
# 25  1202000200  20141103T000000  233000         3       2.00         1710
# 26  1794500383  20140626T000000  937000         3       1.75         2450
# 27  3303700376  20141201T000000  667000         3       1.00         1400
# 28  5101402488  20140624T000000  438000         3       1.75         1520
# 29  1873100390  20150302T000000  719000         4       2.50         2570
# 30  8562750320  20141110T000000  580500         3       2.50         2320
# 31  2426039314  20141201T000000  280000         2       1.50         1190
# 32   461000390  20140624T000000  687500         4       1.75         2330
# 33  7589200193  20141110T000000  535000         3       1.00         1090
# 34  7955080270  20141203T000000  322500         4       2.75         2060
# 35  9547205180  20140613T000000  696000         3       2.50         2300
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
#2. Get the price of the houses located at the longitude--122.045 latitude- 47.6168.
df[(df['lat'] == 47.6168) & (df['long'] == -122.045)]['price']
# Out:
# 4    510000
# Name: price, dtype: int64

# %%
df.corr()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_33952\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# ...

# %%
A = pd.DataFrame([['Carl', 22],['Martha', 25],['Calvin', 12],['Stuart', 15]], 
                 columns=['Name', 'Age']) 
B = pd.DataFrame([['Melvin', 25],['Martha', 34],['Lewis', 32],['Leo', 25]], 
                 columns=['Name', 'Age'])

# %%
A
# Out:
#      Name  Age
# 0    Carl   22
# 1  Martha   25
# 2  Calvin   12
# 3  Stuart   15

# %%
B
# Out:
#      Name  Age
# 0  Melvin   25
# 1  Martha   34
# 2   Lewis   32
# 3     Leo   25

# %%
inner = pd.merge(A, B, on='Age', how='inner') 
#outer = pd.merge(A, B, on='Age', how='outer_join') 
#left_outer = pd.merge(A, B, on='Age', how='left_join') 
#right_outer = pd.merge(A, B, on='Age', how='right_join')

# %%
inner
# Out:
#    Name_x  Age  Name_y
# 0  Martha   25  Melvin
# 1  Martha   25     Leo

# %%
outer = pd.merge(A, B, on='Age', how='outer')

# %%
outer
# Out:
#    Name_x  Age  Name_y
# 0    Carl   22     NaN
# 1  Martha   25  Melvin
# 2  Martha   25     Leo
# 3  Calvin   12     NaN
# 4  Stuart   15     NaN
# 5     NaN   34  Martha
# 6     NaN   32   Lewis
